# %% [markdown]
# <a href="https://colab.research.google.com/github/hilaltekgz/TextGenerator/blob/main/TextGeneration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 3.8 MB 8.3 MB/s
# ...
#      |████████████████████████████████| 6.5 MB 45.7 MB/s
# ...
#      |████████████████████████████████| 895 kB 36.7 MB/s
# ...
#      |████████████████████████████████| 77 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 38.8 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import pipeline

# %%
gpt2_generator = pipeline('text-generation', model='gpt2')
# Out:
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/523M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
sentences = gpt2_generator("To be honest, neural networks", do_sample=True, top_k=50, temperature=0.6, max_length=128, num_return_sequences=3)
for sentence in sentences:
  print(sentence["generated_text"])
  print("="*50)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# To be honest, neural networks are the best at all things. They're very good at recognizing patterns — and there are many types of patterns.
#
# If you look at what it's like to be a child of artificial intelligence, you see that it's very difficult to understand these neural networks.
#
# And we're going to use this to help you understand the human brain.
#
# For example, if you're a human in the middle of a battle, you might be able to recognize the battles, but you might not know the battle. And the human brain is very good at recognizing patterns. The human brain is very good
# ...
# To be honest, neural networks are a lot more complicated than you would think. They're not like any other neural network. They're a bunch of instructions. You can't make a neural network of instructions and have it work at all.
#
# What are the biggest challenges that neural networks face when it comes to training?
#
# ...
